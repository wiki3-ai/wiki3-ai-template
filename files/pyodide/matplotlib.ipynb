# %% [markdown]
# ## Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 7, 777)
plt.plot(x, np.sin(x));

# %%
plt.show()

# %% [markdown]
# ## Matplotlib: support for widgets backend

# %%
# %pip install -q ipympl

# %%
# %matplotlib widget

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x))
